# %%
from __future__ import division, print_function
__author__ = 'Jianghao Zhu CUSP 2016'
import pylab as pl
import json
import os
import sys
import numpy as np
from numpy.random import randn

from pandas import Series, DataFrame
import pandas
import pandas as pd
PUIdata = os.getenv("PUIDATA")
print (PUIdata)
dataDirect = os.getenv("DFDATA")
dataSource = dataDirect + "/h9gi-nx95/1448475295/h9gi-nx95"
print (dataDirect)
print (dataSource)
# Out:
# /home/cusp/jz2575/PUIdata
# /gws/open/NYCOpenData/nycopendata/data
# /gws/open/NYCOpenData/nycopendata/data/h9gi-nx95/1448475295/h9gi-nx95

# %%
# %pylab inline
np.set_printoptions(precision=4, threshold=500)
np.random.seed(456676)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_dmv = pd.read_csv(dataSource)
df_dmv.head(n=9)
# Out:
#          DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  11/22/2015  14:13     QUEENS   11369.0  40.763627 -73.881148
# 1  11/22/2015  14:12   BROOKLYN   11212.0  40.663518 -73.902376
# 2  11/22/2015  14:10        NaN       NaN        NaN        NaN
# 3  11/22/2015  14:10  MANHATTAN   10018.0  40.750661 -73.987779
# 4  11/22/2015   6:40     QUEENS   11420.0  40.665490 -73.819525
# 5  11/22/2015   6:45     QUEENS   11434.0  40.667963 -73.771543
# 6  11/22/2015   6:50   BROOKLYN   11236.0  40.645828 -73.912215
# 7  11/22/2015   6:52  MANHATTAN   10016.0  40.741023 -73.978615
# 8  11/22/2015   7:00        NaN       NaN        NaN        NaN
#
#                     LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0   (40.763627, -73.8811477)                25 AVENUE         88 STREET
# 1   (40.663518, -73.9023763)            POWELL STREET    LIVONIA AVENUE
# 2                        NaN    YELLOWSTONE BOULEVARD     AUSTIN STREET
# ...

# %%
col_list = ['LATITUDE', 'LONGITUDE']
df_accident = df_dmv[col_list]
df_accident.head(n=5)
# Out:
#     LATITUDE  LONGITUDE
# 0  40.763627 -73.881148
# 1  40.663518 -73.902376
# 2        NaN        NaN
# 3  40.750661 -73.987779
# 4  40.665490 -73.819525

# %%
#It is intentional to show only first 1000 datapoints.
#With all datapoints shown, we can not see difference in different 
#locations.
ax = df_accident.head(n=1000).plot.scatter(x='LONGITUDE', 
                    y='LATITUDE', alpha=0.2, label='Location')
ax.set_title("NYPD Motor Vehicle Incidents")
#ax.
pl.show()
